# %% [markdown]
# ___
# <a href='https://www.pau.edu.tr/endustri'><img src= 'data:image/jpeg;base64,... '/></a>
# ___
# # <center><em>IENG435 Problem Çözmede Sezgisel Yöntemler</em></center>

# %% [markdown]
# # <center>Your centered level h1 title</center>

# %% [markdown]
# merhabalar bu benim ilk notum

# %%
merhabalar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12904/2887089189.py in <module>
# ----> 1 merhabalar
#
# NameError: name 'merhabalar' is not defined

# %% [markdown]
# # Başlık
#
# ## Başlık 2
# Alacağınız notlar ...

# %% [markdown]
# # Kısayollar

# %% [markdown]
# Enter --> satır içerisine giriş yapar.
#
# Shift +  Enter --> satır içerisinde yaptığınız işlemleri çalıştırır.

# %%
"merhaba"

# %% [markdown]
# Yön Tuşları Satırlar arasında dolaşmanıza izin verir.

# %% [markdown]
# >**m** Satırı markdown alanına dönüştürür. (İmlecin yanıp sönmüyor olması gerekir.)
#
# >**y** Satırı kod alanına dönüştürür. (İmlecin yanıp sönmüyor olması gerekir.)
#
# >**b** Satırın altına yeni satır ekler. (İmlecin yanıp sönmüyor olması gerekir.)
#
# >**c** Satırı kopyalar. (İmlecin yanıp sönmüyor olması gerekir.)
#
# >**v** Satırı yapıştırır. (İmlecin yanıp sönmüyor olması gerekir.)
#
# >**x** Satır üzerinde kesme/silme işlemi yapar kesilen satır yapıştırılabilir.(İmlecin yanıp sönmüyor olması gerekir.)

# %% [markdown]
# | Kalın yazmak için | **ifade**|
#
# | İtalik yazmak için | *ifade*|
#
# | Üstü çizili yazmak için | ~~ifade~~|

# %% [markdown]
# daha fazla bilgi için; (https://www.markdownguide.org/cheat-sheet)

# %% [markdown]
# **Kalın yazacağım ifade**

# %% [markdown]
# *buda itallik ifadem*

# %% [markdown]
# ~~buda üstü çizili ifadem~~

# %% [markdown]
# > bir kod bloğunu kapalı hale getirmek için ''' .... ''' yapısı kullanılır.
#
# ```
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "age": 25
# }
# ```

# %%
''' a=2 
    b=3
    a+b'''

# %%
'''a=2 
b=3
a+b'''
# Out:
# 'a=2 \nb=3\na+b'

# %% [markdown]
# | Syntax | Description |

# %% [markdown]
# # Başlık
#
# ## başlık

# %% [markdown]
# | ----------- | ----------- |

# %% [markdown]
# Resim ekleme

# %% [markdown]
# ![0%20C_ibLD-RscbJzjMq.png](attachment:0%20C_ibLD-RscbJzjMq.png)

# %%
"merhaba "

# %%
2+3

# %%
print(2+3)
# Out:
# 5

# %% [markdown]
# ![Pa%C3%BC_enm.png](attachment:Pa%C3%BC_enm.png)
